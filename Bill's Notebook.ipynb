# %%
import pandas as pd

# %%
data = pd.read_csv("ks-projects-201801.csv")

# %%
result = data.sort_values(['category'], ascending=[0])

# %%
result.head(3)
# Out:
#                 ID                             name category main_category  \
# 64420   1327603481  Roameroo: Travel Mags and Plans    Zines    Publishing
# 155090  1788711173   #Stock Tips: A Zine About Soup    Zines    Publishing
# 158232  1804856616                SEDITION MAGAZINE    Zines    Publishing
#
#        currency    deadline     goal             launched  pledged  \
# 64420       USD  2014-08-11  33000.0  2014-07-09 18:49:19  6263.00
# 155090      USD  2014-01-25    500.0  2014-01-14 21:38:55  6492.92
# 158232      USD  2016-07-18   2500.0  2016-07-08 22:05:03  2641.00
#
#              state  backers country  usd pledged  usd_pledged_real  \
# 64420       failed       14      US      6263.00           6263.00
# 155090  successful      730      US      6492.92           6492.92
# 158232  successful       38      US       424.00           2641.00
#
#         usd_goal_real
# 64420         33000.0
# 155090          500.0
# 158232         2500.0

# %%
namedata = data.sort_values('name', ascending=False).head(10)

# %%
namedata
# Out:
#                 ID                                               name  \
# 103233  1524766221  €9 Universal Remote Control App for kid mum da...
# 246541   323794635  ‹Darf ich vorstellen? May I introduce?› Kinder...
# 282515   507403134  ••• New Music and Video Art ••• CD/DVD project...
# 374346   977633355                       •Tales of Terrene: Book One•
# 9159    1046239660                         •LiveJackets (Prototype 2)
# 47372   1241383071                    • THE SHIFT •  ( Film + Album )
# 201104  2024003408                                        • Rooftop •
# 158471  1806114726  • My first dream short film • Mon premier cour...
# 56976   1289892447                                     • Greenfinit •
# 370412   957338579  •\tHelp save the honeybees: Provide funding to...
#
#                 category main_category currency    deadline     goal  \
# 103233          Software    Technology      EUR  2015-06-26  19000.0
# ...
